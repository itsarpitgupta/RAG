# %% [markdown]
# # Text Splitters and Chunking Strategies
#
# Demonstrates practical document splitting techniques across various text inputs. Explores chunk size trade-offs, overlap window continuity, and text loader integration.
#
# ## Workflow Architecture
#
# <div align="center">
#   <img src="workflow_chunking_overview.png" alt="Text Splitters and Chunking Strategies Architecture Diagram" width="580" />
# </div>
#
# <details>
# <summary><b>Click to expand Colorful Mermaid Source Code</b></summary>
#
# ```mermaid
# flowchart TD
#     subgraph In["Source Document"]
#         Doc(["Raw Document Corpus"]):::startNode
#     end
#     subgraph Split["Recursive Character Chunking"]
#         Splitter["RecursiveCharacterTextSplitter<br/>(Splits on paragraphs, newlines, spaces)"]:::splitNode
#         Chunk1["Chunk 1 (500 chars)"]:::chunkNode
#         Overlap["Overlap Window (50 chars)<br/>(Maintains Context Continuity)"]:::overlapNode
#         Chunk2["Chunk 2 (500 chars)"]:::chunkNode
#     end
#     subgraph Out["Vector Pipeline"]
#         Emb["HuggingFace MiniLM Embeddings"]:::embNode
#         VS["FAISS Vector Store"]:::vsNode
#     end
#     Doc --> Splitter
#     Splitter --> Chunk1
#     Chunk1 -.-> Overlap
#     Overlap -.-> Chunk2
#     Chunk1 --> Emb
#     Chunk2 --> Emb
#     Emb --> VS
#     classDef startNode fill:#E8F5E9,stroke:#2E7D32,stroke-width:2px,color:#1B5E20;
#     classDef splitNode fill:#E3F2FD,stroke:#1565C0,stroke-width:2px,color:#0D47A1;
#     classDef chunkNode fill:#FFF8E1,stroke:#FFA000,stroke-width:2px,color:#E65100;
#     classDef overlapNode fill:#FCE4EC,stroke:#C2185B,stroke-width:2px,color:#880E4F;
#     classDef embNode fill:#EDE7F6,stroke:#5E35B1,stroke-width:2px,color:#311B92;
#     classDef vsNode fill:#E0F7FA,stroke:#00838F,stroke-width:2px,color:#004D40;
# ```
# </details>
#
# ### Key Chunking Principles
# - **Hierarchical Splitting**: Attempts double-newline splitting first, falling back to single newline and space.
# - **Context Window Preservation**: Overlap ensures sentences that span chunk boundaries are not truncated.
# - **Direct Vector Ingestion**: Prepares text for instant FAISS and Chroma embedding ingestion.

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader(
    file_path="data/text_files/python_intro.txt",
    encoding="utf-8"
)
documents = loader.load()

print(f"metadata : {documents[0].metadata}")
print(f"page content : {documents[0].page_content[:100]}")
# Out:
# metadata : {'source': 'data/text_files/python_intro.txt'}
# page content : Python Programming Introduction
#
# Python is a high-level, interpreted programming language known for

# %%
from langchain_community.document_loaders import DirectoryLoader, TextLoader

dir_loader = DirectoryLoader(
    path="data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    show_progress=True,
    loader_kwargs={'encoding' : 'utf-8'}
)

documents = dir_loader.load()

for i, doc in enumerate(documents):
    print(f"Doc : {i+1}")
    print(f"metadata : {doc.metadata}")
    print(f"page content : {doc.page_content[:100]}....")
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 1454.84it/s]
# Doc : 1
# metadata : {'source': 'data\\text_files\\machine_learning.txt'}
# page content : Machine Learning Basics
#
# Machine learning is a subset of artificial intelligence that enables system....
# Doc : 2
# metadata : {'source': 'data\\text_files\\python_intro.txt'}
# page content : Python Programming Introduction
#
# Python is a high-level, interpreted programming language known for ....

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter, CharacterTextSplitter, TokenTextSplitter

char_split = CharacterTextSplitter(
    separator="\n",
    chunk_size=200,
    chunk_overlap=20,
    length_function=len
)

char_chunks = char_split.split_text(documents[0].page_content)
print(f"original page content: {documents[0].page_content}", sep="\n")
for i, text in enumerate(char_chunks):
    print(f"Chunk : {i+1}")
    print(f"Content : {text[:100]}...")
# Out:
# original page content: Machine Learning Basics
#
# Machine learning is a subset of artificial intelligence that enables systems to learn and improve
# from experience without being explicitly programmed. It focuses on developing computer programs
# that can access data and use it to learn for themselves.
#
# Types of Machine Learning:
# 1. Supervised Learning: Learning with labeled data
# 2. Unsupervised Learning: Finding patterns in unlabeled data
# 3. Reinforcement Learning: Learning through rewards and penalties
#
# Applications include image recognition, speech processing, and recommendation systems
#
#
#
# Chunk : 1
# Content : Machine Learning Basics
# Machine learning is a subset of artificial intelligence that enables systems...
# Chunk : 2
# Content : from experience without being explicitly programmed. It focuses on developing computer programs
# that...
# Chunk : 3
# Content : 1. Supervised Learning: Learning with labeled data
# ...

# %%
recursive_spliter = RecursiveCharacterTextSplitter(
    separators=[" "],
    chunk_size = 200,
    chunk_overlap = 100,
    length_function = len
)


char_chunks = recursive_spliter.split_text(documents[0].page_content)
for i, text in enumerate(char_chunks):
    print(f"Chunk : {i+1}")
    print(f"Content : {text}")
# Out:
# Chunk : 1
# Content : Machine Learning Basics
#
# Machine learning is a subset of artificial intelligence that enables systems to learn and improve
# from experience without being explicitly programmed. It focuses on developing
# Chunk : 2
# Content : to learn and improve
# from experience without being explicitly programmed. It focuses on developing computer programs
# that can access data and use it to learn for themselves.
#
# Types of Machine
# Chunk : 3
# Content : computer programs
# that can access data and use it to learn for themselves.
#
# Types of Machine Learning:
# 1. Supervised Learning: Learning with labeled data
# 2. Unsupervised Learning: Finding patterns in
# Chunk : 4
# Content : Supervised Learning: Learning with labeled data
# 2. Unsupervised Learning: Finding patterns in unlabeled data
# 3. Reinforcement Learning: Learning through rewards and penalties
#
# Applications include
# Chunk : 5
# Content : data
# ...

# %%
token_splitter = TokenTextSplitter(chunk_size=50, chunk_overlap=10)
token_chunk = token_splitter.split_text(documents[0].page_content)
print(f"Created {len(token_chunk)} chunk")

for i, text in enumerate(token_chunk):
    print(f"Chunk : {i+1}")
    print(f"Content : {text}")
# Out:
# Created 3 chunk
# Chunk : 1
# Content : Machine Learning Basics
#
# Machine learning is a subset of artificial intelligence that enables systems to learn and improve
# from experience without being explicitly programmed. It focuses on developing computer programs
# that can access data and use it to learn for themselves.
#
# Types
# Chunk : 2
# Content :  use it to learn for themselves.
#
# Types of Machine Learning:
# 1. Supervised Learning: Learning with labeled data
# 2. Unsupervised Learning: Finding patterns in unlabeled data
# 3. Reinforcement Learning: Learning through rewards
# Chunk : 3
# Content :
# 3. Reinforcement Learning: Learning through rewards and penalties
#
# Applications include image recognition, speech processing, and recommendation systems
